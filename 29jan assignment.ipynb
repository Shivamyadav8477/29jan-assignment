# %%
Qus1- who developed python programming language?
ans- Guido van rossum

Qus2- which type of programming does python support?
ans- object-oriented programming, structured programming, functional programming.

Qus3- is python case senstive when dealing with identifiers?
ans- yes, python is case senstive (case is always significant while dealing with identifiers in python).

Qus4- what is the correct exetension of the python file?
ans- .py


Qus5- is python code compiled or interpreted?
ans- python is an interpreted language.

Qus6-Name a few blocks of codes use to define in python language?
ans- a module, a function body, and a class defintion.

Qus-7 state a character used to give single - comments in python ?
ans- hash character (#).
    
Qus-8 mention functions which can help us to find the version of python that we are currently working on?
ans- the function sys.version can help us to find the version of python.
    
Qus9- python supports the creation of anonymous function at runtime, using a construct called_ _ _ _ _?
ans- lambda
    
Qus10- what does pip stand for python?
ans-preferred installer program.
    
Qus-11 mention a few built- in functions in python?
ans- print()
    type()
    abs()
    dir()
    sum()
    count()
    avg()
    
    
Qus-12 what is the maximum possible length of an identifier in python?
ans-in python, the highest possible length of an identifier is 79 characters.
    
Qus13-what are benefits of using python?
ans-easy to learn and easy to use, python is one of the most popular programming language in the world,extensive libraries, write less do more,portability,wide range of use cases. 
    
Qus14- how is memory managed in python?
ans- involves a private heap containing all python objects and data structures.
    
Qus15- how to install python on windows and set path variables?
ans- 1 right- clicking the pc and going to properties
    2 clicking on the advanced system settings in the menu on the left
    3 clicking on the environment variables button on the bottom right 
    4 in the system variable section , selcting the path variables and clicking on edit . the next screen will be show all the directories that are tha currently a part of the path variable .
    5 clicking on new and entering python's install directory.
    
Qus16- is identation required in python?
ans-  identation is mandatory in python to define the blocks of statement.
